# %%
measurementsdf=spark.read.load("fit_store/hortovanyi.measurement.parquet")
measurementsdf.cache()
measurementsdf.show()
# Out:
# +-------------+----------+----------+-------------+--------+-----------------+-----+-------+---------+-------+-------------------+------------------+
# |measurementId|    source|activityId|    timestamp|distance|         altitude|speed|cadence|heartRate|airTemp|             posLat|           posLong|
# +-------------+----------+----------+-------------+--------+-----------------+-----+-------+---------+-------+-------------------+------------------+
# |   1443218330|1:1036:330|1443217422|1443218330000| 5434.73|4.199999999999989|7.271|     76|        0|     20| -28.04458586499095|153.43793367035687|
# |   1443218339|1:1036:330|1443217422|1443218339000| 5499.75|4.199999999999989|7.159|     75|        0|     20|-28.045196486636996|153.43808244913816|
# |   1443218340|1:1036:330|1443217422|1443218340000| 5506.86|4.199999999999989|7.184|     75|        0|     20|-28.045263290405273|153.43810306861997|
# ...
